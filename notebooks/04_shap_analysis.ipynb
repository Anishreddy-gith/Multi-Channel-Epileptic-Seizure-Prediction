# %% [markdown]
# # 04 - Explainability and Paper Package Demo
#
# This notebook is a safe explainability/paper-package walkthrough. The final frozen package did not include validated SHAP result figures, so this notebook shows where SHAP code lives and how to discuss explainability honestly.

# %%
from pathlib import Path
import sys

# Run notebooks from either the repository root or the notebooks/ folder.
PROJECT_ROOT = Path.cwd()
if PROJECT_ROOT.name == 'notebooks':
    PROJECT_ROOT = PROJECT_ROOT.parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print('Project root:', PROJECT_ROOT)
print('Paper package:', PROJECT_ROOT / 'paper')

# %% [markdown]
# ## Explainability code status
#
# The repository contains SHAP-related scripts under `src/explainability/`, but the final paper package is based on audited metrics and figures rather than new SHAP results. Do not claim SHAP findings unless you generate and validate them separately.

# %%
from pathlib import Path

explainability_dir = PROJECT_ROOT / 'src/explainability'
for p in sorted(explainability_dir.glob('*.py')):
    print(p.relative_to(PROJECT_ROOT), 'size=', p.stat().st_size)

# %% [markdown]
# ## Paper package files for demo

# %%
from IPython.display import display
import pandas as pd

manifest = pd.read_csv(PROJECT_ROOT / 'paper/tables/paper_package_manifest.csv')
display(manifest.head(20))
print('Total package files indexed:', len(manifest))

# %% [markdown]
# ## Final manuscript and validation report

# %%
from pathlib import Path

for path in [PROJECT_ROOT / 'paper/conference_paper.md', PROJECT_ROOT / 'outputs/paper/FINAL_VALIDATION_REPORT.md']:
    print('---', path.relative_to(PROJECT_ROOT))
    text = path.read_text(encoding='utf-8')
    print(text[:1500])
    print()

# %% [markdown]
# ## Publication figures overview

# %%
from IPython.display import Image, display

for fig in ['pipeline_diagram.png', 'model_comparison_chart.png', 'preictal_horizon_pr_auc.png']:
    print(fig)
    display(Image(filename=str(PROJECT_ROOT / 'paper/figures' / fig)))

# %% [markdown]
# ## Optional SHAP command - not run by default
#
# The command below is only a pointer to the script. Run it only after choosing a validated checkpoint and a small demo batch.

# %%
# Optional future explainability command; not part of the frozen final results.
# !python src/explainability/shap_explainer.py --help
